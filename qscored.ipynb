# %%
import os
from os.path import exists
import numpy as np
import pandas as pd

# %%
projects = os.listdir("metrics")
projects
# Out:
# ['argouml-v0.35.1',
#  'checkstyle-v8.39',
#  'freemind-v1.0.0',
#  'ganttproject-v2.8.11',
#  'GoGreen-v.0.1.3',
#  'ipscan-v3.7.3',
#  'jEdit-v5.5.0',
#  'JetUML-v3.1',
#  'jpass-v0.1.20',
#  'keystore-explorer-v5.4.4',
#  'LiveChatServer-v4.1',
#  'LogFX-v0.9.1',
#  'mars-sim-v3.1.0',
#  'pgptool-v0.5.9.2',
#  'sweethome3d-5.6']

# %%
h = "project,loc,archSmellCount,dsgnSmellCount,implSmellCount,qualityScore".split(",")

# %%
from platform import architecture
import xml.etree.ElementTree as ET

weight = (0.5, 0.3, 0.2)

rows = []
for prj in projects:
  file = f"smells/{prj}/DesigniteAnalysis.xml"
  if exists(file):
    root = ET.parse(f"smells/{prj}/DesigniteAnalysis.xml")
    loc = int(root.find(".//Solution/LOC").text)
    arch = int(root.find(".//Solution/TotalArchSmellCount").text)
    dsgn = int(root.find(".//Solution/TotalDesignSmellCount").text)
    impl = int(root.find(".//Solution/TotalImplSmellCount").text)
    dens = tuple((1000/loc)*x for x in (arch,dsgn,impl))
    score = np.dot(weight,dens)
    rows.append([prj,loc,arch,dsgn,impl,score])

df = pd.DataFrame(rows, columns=h)

df.sort_values('qualityScore')
# Out:
#                      project     loc  archSmellCount  dsgnSmellCount  \
# 0            argouml-v0.35.1  192288             213            1702
# 1            freemind-v1.0.0   62682             128             622
# 2       ganttproject-v2.8.11   55902             178             591
# 12          pgptool-v0.5.9.2   17331             103             176
# 10              LogFX-v0.9.1    3809              16              43
# 3            GoGreen-v.0.1.3    3402              12              40
# 8   keystore-explorer-v5.4.4   51636             121             258
# 5               jEdit-v5.5.0   82976             186             955
# 4              ipscan-v3.7.3   14773              52             258
# 7              jpass-v0.1.20    3628              10              14
# 11           mars-sim-v3.1.0  206159             265            1252
# 13           sweethome3d-5.6   87690              14             551
# 9        LiveChatServer-v4.1    2026               2              24
# 6                JetUML-v3.1   20414              41             201
#
#     implSmellCount  qualityScore
# 0             4364      7.748273
# 1             2158     10.883507
# 2             1936     11.690101
# 12             681     13.876868
# 10             172     14.518246
# 3              178     15.755438
# 8             3533     16.354869
# 5             5445     17.697889
# 4             1041     21.092534
# 7              392     24.145535
# 11           27964     29.593178
# 13           12446     30.351237
# 9              276     31.293189
# 6             4382     46.889390

# %%
list(df.sort_values('qualityScore')['project'])
# Out:
# ['argouml-v0.35.1',
#  'freemind-v1.0.0',
#  'ganttproject-v2.8.11',
#  'pgptool-v0.5.9.2',
#  'LogFX-v0.9.1',
#  'GoGreen-v.0.1.3',
#  'keystore-explorer-v5.4.4',
#  'jEdit-v5.5.0',
#  'ipscan-v3.7.3',
#  'jpass-v0.1.20',
#  'mars-sim-v3.1.0',
#  'sweethome3d-5.6',
#  'LiveChatServer-v4.1',
#  'JetUML-v3.1']
